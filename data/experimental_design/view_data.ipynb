# %%
import pandas as pd 
data = pd.read_csv("Exp.design.csv")

# %%
data
# Out:
#         epsilon    rho  alfa  Eta.re  Eta.ce  Gamma.re  Gamma.ce  Nu.re  \
# 0      3.000000  0.001  0.33    0.02    0.02      0.25      0.25   0.02
# 1      3.777778  0.001  0.33    0.02    0.02      0.25      0.25   0.02
# 2      4.555556  0.001  0.33    0.02    0.02      0.25      0.25   0.02
# 3      5.333333  0.001  0.33    0.02    0.02      0.25      0.25   0.02
# 4      6.111111  0.001  0.33    0.02    0.02      0.25      0.25   0.02
# ...         ...    ...   ...     ...     ...       ...       ...    ...
# 5395   6.888889  0.015  0.33    0.02    0.02      0.25      0.25   0.02
# 5396   7.666667  0.015  0.33    0.02    0.02      0.25      0.25   0.02
# 5397   8.444444  0.015  0.33    0.02    0.02      0.25      0.25   0.02
# 5398   9.222222  0.015  0.33    0.02    0.02      0.25      0.25   0.02
# 5399  10.000000  0.015  0.33    0.02    0.02      0.25      0.25   0.02
#
#       Nu.ce  k.re  ...  Beta.Delta.Temp    CO2.base  CO2.Disaster  \
# ...
